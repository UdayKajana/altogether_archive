# %%
RAG — Retrieval-Augmented Generation
LLMs like ChatGPT know only what they were trained on. RAG fixes this by letting the LLM fetch real, up-to-date, or private information before answering.

How RAG Works — 3 Steps:
User Question
     │
     ▼
1. RETRIEVE  →  Search your knowledge base for relevant chunks
     │
     ▼
2. AUGMENT   →  Inject those chunks into the LLM prompt
     │
     ▼
3. GENERATE  →  LLM answers using retrieved context
